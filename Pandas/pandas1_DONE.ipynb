# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['a'] = [20, 30, 40]
df['b'] = ['one', 'two', 'three']
df
# Out:
#     a      b
# 0  20    one
# 1  30    two
# 2  40  three

# %%
data = pd.read_csv('train.csv')
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.shape
# Out:
# (891, 12)

# %%
data.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
data[['Age', 'Sex']].head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
data.loc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data.loc[1:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df = pd.DataFrame()
df['Name'] = ['Tom', 'Jack', 'Nick']
df['Mark'] = [33, 55, 66]
df.index = [1, 2, 3]
df
# Out:
#    Name  Mark
# 1   Tom    33
# 2  Jack    55
# 3  Nick    66

# %%
df.loc[1]
# Out:
# Name    Tom
# Mark     33
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Jack
# Mark      55
# Name: 2, dtype: object

# %%
data[data.Sex == 'female'].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
data[data.Pclass == 1].tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# 889      0  111369  30.0000         C148        C

# %%
data[data.Pclass.isin([1,2])].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %%
data[data.Age < 16].head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 7             8         0       3        Palsson, Master. Gosta Leonard
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16           17         0       3                  Rice, Master. Eugene
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 7     male   2.0      3      1   349909  21.0750   NaN        S
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 16    male   2.0      4      1   382652  29.1250   NaN        Q

# %%
data[(data.Sex == 'female') & (data.Age > 18) & (data.Age < 25) & (data.SibSp == 0) & (data.Parch == 0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 44            45         1       3
# 56            57         1       2
# 106          107         1       3
# 141          142         1       3
# 199          200         0       2
# 289          290         1       3
# 293          294         0       3
# 310          311         1       1
# 345          346         1       2
# 369          370         1       1
# 376          377         1       3
# 404          405         0       3
# 427          428         1       2
# 473          474         1       2
# 474          475         0       3
# 501          502         0       3
# 554          555         1       3
# 627          628         1       1
# 641          642         1       1
# 649          650         1       3
# 708          709         1       1
# 710          711         1       1
# 816          817         0       3
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 44                       Devaney, Miss. Margaret Delia  female  19.0      0
# 56                                   Rugg, Miss. Emily  female  21.0      0
# 106                   Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# 141                           Nysten, Miss. Anna Sofia  female  22.0      0
# 199             Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0      0
# 289                               Connolly, Miss. Kate  female  22.0      0
# 293                                Haas, Miss. Aloisia  female  24.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 345                      Brown, Miss. Amelia "Mildred"  female  24.0      0
# 369                      Aubart, Mme. Leontine Pauline  female  24.0      0
# 376                    Landergren, Miss. Aurora Adelia  female  22.0      0
# 404                            Oreskovic, Miss. Marija  female  20.0      0
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
# 473       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.0      0
# 474                        Strandberg, Miss. Ida Sofia  female  22.0      0
# 501                                Canavan, Miss. Mary  female  21.0      0
# 554                                 Ohman, Miss. Velin  female  22.0      0
# 627                      Longley, Miss. Gretchen Fiske  female  21.0      0
# 641                               Sagesser, Mlle. Emma  female  24.0      0
# 649                    Stanley, Miss. Amy Zillah Elsie  female  23.0      0
# 708                               Cleaver, Miss. Alice  female  22.0      0
# 710   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  female  24.0      0
# 816                       Heininen, Miss. Wendla Maria  female  23.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket      Fare Cabin Embarked
# 44       0            330958    7.8792   NaN        Q
# 56       0        C.A. 31026   10.5000   NaN        S
# 106      0            343120    7.6500   NaN        S
# 141      0            347081    7.7500   NaN        S
# 199      0            248747   13.0000   NaN        S
# 289      0            370373    7.7500   NaN        Q
# 293      0            349236    8.8500   NaN        S
# 310      0             11767   83.1583   C54        C
# 345      0            248733   13.0000   F33        S
# 369      0          PC 17477   69.3000   B35        C
# 376      0            C 7077    7.2500   NaN        S
# 404      0            315096    8.6625   NaN        S
# 427      0            250655   26.0000   NaN        S
# 473      0   SC/AH Basle 541   13.7917     D        C
# 474      0              7553    9.8375   NaN        S
# 501      0            364846    7.7500   NaN        Q
# 554      0            347085    7.7750   NaN        S
# 627      0             13502   77.9583    D9        S
# 641      0          PC 17477   69.3000   B35        C
# 649      0          CA. 2314    7.5500   NaN        S
# 708      0            113781  151.5500   NaN        S
# 710      0          PC 17482   49.5042   C90        C
# 816      0  STON/O2. 3101290    7.9250   NaN        S
# 882      0              7552   10.5167   NaN        S
# 887      0            112053   30.0000   B42        S

# %%
data[(data.Sex == 'male') & (data.Age < 50) & (data.Age > 18) & (data.SibSp == 0)].shape
# Out:
# (256, 12)

# %% [markdown]
# Задание:
#
# 1) Посчитайте количество пассажиров первого класса, которые сели на борт в Саутгемптоне.
#
# 2) Солько пассажиров третьего класса, которые путешествовали в компании 2 или более родственников (братьев / сестер / супругов)?
#
# 3) Сколько в среднем стоил билет первого класса?
#
# Описание признаков:
#
# **PassengerId** - id пассажира
#
# **Survived** бинарная переменная: выжил пассажирил (1) или нет (0)
#
# **Pclass** - класс пассажира
#
# **Name** - имя пассажира
#
# **Sex** - пол пассажира
#
# **Age** - возраст пассажира
#
# **SibSp** - количество родственников (братьев, сестер, супругов) пассажира на борту
#
# **Parch** - количество родственников (родителей / детей) пассажира на борту
#
# **Ticket** - номер билета
#
# **Fare** - тариф (стоимость билета)
#
# **Cabin** - номер кабины
#
# **Embarked** - порт, в котором пассажир сел на борт (C - Cherbourg, S - Southampton, Q = Queenstown)

# %%
#1 
data[(data.Pclass == 1) & (data.Embarked == 'S')].shape
# Out:
# (127, 12)

# %%
#2
data[(data.Pclass == 3) & (data.SibSp >= 2)].shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #2
# ----> 2 data[(data.Pclass == 3) & (data.SibSp >= 2)].shape
#
# NameError: name 'data' is not defined

# %%
#3
ff = data[data.Pclass == 1]
ff.Fare.mean()
# Out:
# np.float64(84.1546875)

# %%
data['Family'] = data['SibSp'] + data['Parch']
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked  Family
# 0       0         A/5 21171   7.2500   NaN        S       1
# 1       0          PC 17599  71.2833   C85        C       1
# 2       0  STON/O2. 3101282   7.9250   NaN        S       0
# 3       0            113803  53.1000  C123        S       1
# 4       0            373450   8.0500   NaN        S       0
# 5       0            330877   8.4583   NaN        Q       0
# 6       0             17463  51.8625   E46        S       0
# 7       1            349909  21.0750   NaN        S       4
# 8       2            347742  11.1333   NaN        S       2
# 9       0            237736  30.0708   NaN        C       1
# 10      1           PP 9549  16.7000    G6        S       2
# 11      0            113783  26.5500  C103        S       0
# 12      0         A/5. 2151   8.0500   NaN        S       0
# 13      5            347082  31.2750   NaN        S       6
# 14      0            350406   7.8542   NaN        S       0
# 15      0            248706  16.0000   NaN        S       0
# 16      1            382652  29.1250   NaN        Q       5
# 17      0            244373  13.0000   NaN        S       0
# 18      0            345763  18.0000   NaN        S       1
# 19      0              2649   7.2250   NaN        C       0

# %%
data['Alone'] = data['Family'].apply(lambda x: 1 if x == 0 else 0)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family  Alone
# 0      0         A/5 21171   7.2500   NaN        S       1      0
# 1      0          PC 17599  71.2833   C85        C       1      0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0      1
# 3      0            113803  53.1000  C123        S       1      0
# 4      0            373450   8.0500   NaN        S       0      1

# %%
data.loc[0]['Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.loc[0]['Name'].split('.')[0].split(',')[1].strip()
# Out:
# 'Mr'

# %%
def return_title(full_name):
    return(full_name.split('.')[0].split(',')[1].strip())

# %%
data['Title'] = data.Name.apply(return_title)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked  Family  Alone Title
# 0      0   7.2500   NaN        S       1      0    Mr
# 1      0  71.2833   C85        C       1      0   Mrs
# 2      0   7.9250   NaN        S       0      1  Miss
# 3      0  53.1000  C123        S       1      0   Mrs
# 4      0   8.0500   NaN        S       0      1    Mr

# %%
del data['Ticket']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 del data['Ticket']
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:4506, in NDFrame.__delitem__(self, key)
#    4501             deleted = True
#    4502 if not deleted:
#    4503     # If the above loop ran and didn't delete anything because
#    4504     # there was no match, this call should raise the appropriate
#    4505     # exception:
# -> 4506     loc = self.axes[-1].get_loc(key)
#    4507     self._mgr = self._mgr.idelete(loc)
#    4509 # delete from the caches
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Ticket'

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch     Fare Cabin Embarked  Family  Alone   Title
# 0       0   7.2500   NaN        S       1      0      Mr
# 1       0  71.2833   C85        C       1      0     Mrs
# 2       0   7.9250   NaN        S       0      1    Miss
# 3       0  53.1000  C123        S       1      0     Mrs
# 4       0   8.0500   NaN        S       0      1      Mr
# 5       0   8.4583   NaN        Q       0      1      Mr
# 6       0  51.8625   E46        S       0      1      Mr
# 7       1  21.0750   NaN        S       4      0  Master
# 8       2  11.1333   NaN        S       2      0     Mrs
# 9       0  30.0708   NaN        C       1      0     Mrs
# 10      1  16.7000    G6        S       2      0    Miss
# 11      0  26.5500  C103        S       0      1    Miss
# 12      0   8.0500   NaN        S       0      1      Mr
# 13      5  31.2750   NaN        S       6      0      Mr
# 14      0   7.8542   NaN        S       0      1    Miss
# 15      0  16.0000   NaN        S       0      1     Mrs
# 16      1  29.1250   NaN        Q       5      0  Master
# 17      0  13.0000   NaN        S       0      1      Mr
# 18      0  18.0000   NaN        S       1      0     Mrs
# 19      0   7.2250   NaN        C       0      1     Mrs

# %%
data['Title'].value_counts()
# Out:
# Title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: count, dtype: int64

# %%
data['Title'] = data['Title'].apply(lambda x: 'Misc' if x not in ['Mr', 'Miss', 'Mrs', 'Master'] else x)

# %%
data['Title'].value_counts()
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Misc       27
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
print(data['Age'].mean())
print(data['Age'].max())
# Out:
# 29.69911764705882
# 80.0

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Family       Alone
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.904602    0.602694
# std      0.806057   49.693429    1.613459    0.489615
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000    0.000000
# 50%      0.000000   14.454200    0.000000    1.000000
# 75%      0.000000   31.000000    1.000000    1.000000
# max      6.000000  512.329200   10.000000    1.000000

# %%
data.sort_values(by = ['Age']).head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch     Fare Cabin Embarked  Family  Alone   Title
# 803  0.42      0      1   8.5167   NaN        C       1      0  Master
# 755  0.67      1      1  14.5000   NaN        S       2      0  Master
# 644  0.75      2      1  19.2583   NaN        C       3      0    Miss
# 469  0.75      2      1  19.2583   NaN        C       3      0    Miss
# 78   0.83      0      2  29.0000   NaN        S       2      0  Master

# %%
data.sort_values(by = ['Age'], ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Family  Alone Title
# 630  male  80.0      0      0  30.0000   A23        S       0      1    Mr
# 851  male  74.0      0      0   7.7750   NaN        S       0      1    Mr
# 493  male  71.0      0      0  49.5042   NaN        C       0      1    Mr
# 96   male  71.0      0      0  34.6542    A5        C       0      1    Mr
# 116  male  70.5      0      0   7.7500   NaN        Q       0      1    Mr

# %%
data.sort_values(by = ['Age', 'Fare'], ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                        Svensson, Mr. Johan
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 456          457         0       1                  Millet, Mr. Francis Davis
# 280          281         0       3                           Duane, Mr. Frank
# 438          439         0       1                          Fortune, Mr. Mark
# 545          546         0       1               Nicholson, Mr. Arthur Ernest
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 252          253         0       1                  Stead, Mr. William Thomas
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
#
#         Sex   Age  SibSp  Parch      Fare        Cabin Embarked  Family  \
# 630    male  80.0      0      0   30.0000          A23        S       0
# 851    male  74.0      0      0    7.7750          NaN        S       0
# 493    male  71.0      0      0   49.5042          NaN        C       0
# 96     male  71.0      0      0   34.6542           A5        C       0
# 116    male  70.5      0      0    7.7500          NaN        Q       0
# 745    male  70.0      1      1   71.0000          B22        S       2
# 672    male  70.0      0      0   10.5000          NaN        S       0
# 33     male  66.0      0      0   10.5000          NaN        S       0
# 54     male  65.0      0      1   61.9792          B30        C       1
# 456    male  65.0      0      0   26.5500          E38        S       0
# 280    male  65.0      0      0    7.7500          NaN        Q       0
# 438    male  64.0      1      4  263.0000  C23 C25 C27        S       5
# 545    male  64.0      0      0   26.0000          NaN        S       0
# 275  female  63.0      1      0   77.9583           D7        S       1
# 483  female  63.0      0      0    9.5875          NaN        S       0
# 829  female  62.0      0      0   80.0000          B28      NaN       0
# 252    male  62.0      0      0   26.5500          C87        S       0
# 555    male  62.0      0      0   26.5500          NaN        S       0
# 570    male  62.0      0      0   10.5000          NaN        S       0
# 170    male  61.0      0      0   33.5000          B19        S       0
#
#      Alone Title
# 630      1    Mr
# 851      1    Mr
# 493      1    Mr
# 96       1    Mr
# 116      1    Mr
# 745      0  Misc
# 672      1    Mr
# 33       1    Mr
# 54       0    Mr
# 456      1    Mr
# 280      1    Mr
# 438      0    Mr
# 545      1    Mr
# 275      0  Miss
# 483      1   Mrs
# 829      1   Mrs
# 252      1    Mr
# 555      1    Mr
# 570      1    Mr
# 170      1    Mr

# %%
data.sort_values(by = ['Age', 'Fare'], ascending=[False, True]).head(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked  Family  Alone Title
# 630  male  80.0      0      0  30.0000   A23        S       0      1    Mr
# 851  male  74.0      0      0   7.7750   NaN        S       0      1    Mr
# 96   male  71.0      0      0  34.6542    A5        C       0      1    Mr
# 493  male  71.0      0      0  49.5042   NaN        C       0      1    Mr
# 116  male  70.5      0      0   7.7500   NaN        Q       0      1    Mr

# %%
data.groupby('Sex')

# %%
data.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
data.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# Задание: отличается ли распределение выживших и не выживших среди мужчин и женщин?

# %%
data.groupby('Sex')['Survived'].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
data.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
pip install matplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting matplotlib>=3.1.1 (from matplot)
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.1.1->matplot)
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1.1->matplot)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1.1->matplot)
#   Downloading fonttools-4.57.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1.1->matplot)
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.1.1->matplot) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.1.1->matplot) (24.2)
# Collecting pillow>=8 (from matplotlib>=3.1.1->matplot)
#   Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.1.1->matplot)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.1.1->matplot)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting websocket-client (from pyloco>=0.0.134->matplot)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-6.1.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#   Preparing metadata (setup.py) ... done
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: zipp>=3.1.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.1->matplot) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.15.0)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests>=2.20 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from twine->pyloco>=0.0.134->matplot) (2.32.3)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from twine->pyloco>=0.0.134->matplot) (2.2.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from twine->pyloco>=0.0.134->matplot) (8.5.0)
# Collecting keyring>=15.1 (from twine->pyloco>=0.0.134->matplot)
#   Downloading keyring-25.6.0-py3-none-any.whl.metadata (20 kB)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich>=12.0.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting id (from twine->pyloco>=0.0.134->matplot)
#   Downloading id-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jaraco.classes (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.functools-4.1.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.context-6.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.2.21-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (2.0 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.8.30)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (4.12.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting backports.tarfile (from jaraco.context->keyring>=15.1->twine->pyloco>=0.0.134->matplot)
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
# Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.3 MB/s eta 0:00:00a 0:00:010m
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 899.6 kB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading twine-6.1.0-py3-none-any.whl (40 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading keyring-25.6.0-py3-none-any.whl (39 kB)
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading id-1.5.0-py3-none-any.whl (13 kB)
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 1.9 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading nh3-0.2.21-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-6.0.1-py3-none-any.whl (6.8 kB)
# Downloading jaraco.functools-4.1.0-py3-none-any.whl (10 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (setup.py) ... done
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9684 sha256=d85e696c3421a997f05b6727513f0570ecda4c68c8c460d7e968e0e3548a1a74
#   Stored in directory: /Users/elizavetakadochnikova/Library/Caches/pip/wheels/54/20/6b/a4ce68b72f26f10cdd3280976de363886c9172be1374666c3d
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=cf702ffede3ce84875146b20ca61e789a031dd6475dcf13db1edef141fcbc766
#   Stored in directory: /Users/elizavetakadochnikova/Library/Caches/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
#   Building wheel for ushlex (setup.py) ... done
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4415 sha256=8b7e8684a0f5116d90227493339dcef4c1d4fda24c771c8e5bc730bd44fc001e
#   Stored in directory: /Users/elizavetakadochnikova/Library/Caches/pip/wheels/30/e7/e6/d3f198618450ea67a8950ebbefbcddffee32b034187ed8c3f9
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, websocket-client, typing, rfc3986, pyparsing, pillow, nh3, more-itertools, mdurl, kiwisolver, importlib-resources, fonttools, docutils, cycler, contourpy, backports.tarfile, requests-toolbelt, readme-renderer, matplotlib, markdown-it-py, jaraco.functools, jaraco.context, jaraco.classes, id, rich, keyring, twine, pyloco, matplot
# Successfully installed SimpleWebSocketServer-0.1.2 backports.tarfile-1.2.0 contourpy-1.3.0 cycler-0.12.1 docutils-0.21.2 fonttools-4.57.0 id-1.5.0 importlib-resources-6.5.2 jaraco.classes-3.4.0 jaraco.context-6.0.1 jaraco.functools-4.1.0 keyring-25.6.0 kiwisolver-1.4.7 markdown-it-py-3.0.0 matplot-0.1.9 matplotlib-3.9.4 mdurl-0.1.2 more-itertools-10.6.0 nh3-0.2.21 pillow-11.2.1 pyloco-0.0.139 pyparsing-3.2.3 readme-renderer-44.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-14.0.0 twine-6.1.0 typing-3.7.4.3 ushlex-0.99.1 websocket-client-1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data.Age.hist()
# Out:
# <Axes: >

# %%
data.Age.hist(bins = 20)
# Out:
# <Axes: >

# %%
data[data.Sex == 'male'].Age.hist()
# Out:
# <Axes: >

# %% [markdown]
# Задание: постройте гистограмму для распределения стоимости билетов (Fare).

# %%
data.Fare.hist()
# Out:
# <Axes: >

# %% [markdown]
# Задание: сравните гистограммы распределения стоимости билетов для разных классов (Pclass).

# %%
data[data.Pclass == 1].Fare.hist()
# Out:
# <Axes: >

# %%
data[data.Pclass == 2].Fare.hist()
# Out:
# <Axes: >

# %%
data[data.Pclass == 3].Fare.hist()
# Out:
# <Axes: >

# %%
data.groupby('Pclass').size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
data.groupby('Pclass').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
data.groupby('Pclass').size().plot(kind = 'pie', title = 'Passenger Classes')
# Out:
# <Axes: title={'center': 'Passenger Classes'}>

# %%
data.groupby('Embarked').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# Задание: постройте по гистограмме и круговой диаграмме для еще двух категориальных признаков.

# %%
data.groupby('Sex').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
data.groupby('Sex').size().plot(kind = 'pie')
# Out:
# <Axes: >

# %%
data.groupby('Embarked').size().plot(kind = 'pie')
# Out:
# <Axes: >

# %%
data.groupby(['Survived'])['Sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived,Sex'>

# %%
data.groupby(['Survived'])['Sex'].value_counts()
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: count, dtype: int64

# %%
data.groupby(['Survived'])['Sex'].value_counts().unstack()
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
data.groupby(['Survived'])['Sex'].value_counts().unstack().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
data.groupby(['Survived'])['Sex'].value_counts().unstack().plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Survived'>

# %%
data.to_csv('new_tit.csv')

# %%
data.Age.hist()
# Out:
# <Axes: >

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.distplot(data.Age.dropna())
# Out:
# /var/folders/3h/y_h_gk8j16xdnzw4h9_54dvh0000gn/T/ipykernel_16189/814215227.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Age.dropna())
# <Axes: xlabel='Age', ylabel='Density'>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/elizavetakadochnikova/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 1.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import norm

# %%
sns.distplot(data.Age.dropna(), fit = norm)
# Out:
# /var/folders/3h/y_h_gk8j16xdnzw4h9_54dvh0000gn/T/ipykernel_16189/225741632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Age.dropna(), fit = norm)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Как распределние возраста выглядит относительно нормального?
#
# **Задание:** постройте распределение цены билетов, как он выглядит относительно нормального распределения?

# %%
sns.distplot(data.Fare.dropna(), fit = norm)
# Out:
# /var/folders/3h/y_h_gk8j16xdnzw4h9_54dvh0000gn/T/ipykernel_16189/2344172585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Fare.dropna(), fit = norm)
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
data.Age.min()
# Out:
# np.float64(0.42)

# %%
data.Age.max()
# Out:
# np.float64(80.0)

# %% [markdown]
# Задание

# %%
min_fare = data.Fare.min()
max_fare = data.Fare.max()

print(f'Минимальная стоимость билета на Титанике составляла {min_fare}, а максимальная - {max_fare}')
# Out:
# Минимальная стоимость билета на Титанике составляла 0.0, а максимальная - 512.3292

# %%
data.Age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
mean_fare = data.Fare.mean()
print(f'Средняя стоимость билета на Титанике составляла {mean_fare}')
# Out:
# Средняя стоимость билета на Титанике составляла 32.204207968574636

# %%
data[['Pclass', 'Age']].groupby('Pclass').mean()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
data.Age.median()
# Out:
# np.float64(28.0)

# %%
median_fare = data.Fare.median()
print(f'Медиана стоимости билета на Титанике составляла {median_fare}')
# Out:
# Медиана стоимости билета на Титанике составляла 14.4542

# %%
data.Pclass.mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %%
data.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data[['Pclass', 'Age']].groupby('Pclass').std()
# Out:
#               Age
# Pclass
# 1       14.802856
# 2       14.001077
# 3       12.495398

# %%
data[data.Pclass == 1].Age.hist()
# Out:
# <Axes: >

# %%
data[data.Pclass == 2].Age.hist()
# Out:
# <Axes: >

# %% [markdown]
# Вопросы:
# - Как еще можно назвать 50%-перцентиль?
# МЕДИАНА
# - Что значит фраза "75%-перцентиль стоимости билетов на Титаник была равна 31"?
# 75% билетов были не дороже 31

# %%
data.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data.Age.hist(bins = 24)
# Out:
# <Axes: >

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
data.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data.Pclass.mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Family       Alone
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.904602    0.602694
# std      0.806057   49.693429    1.613459    0.489615
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000    0.000000
# 50%      0.000000   14.454200    0.000000    1.000000
# 75%      0.000000   31.000000    1.000000    1.000000
# max      6.000000  512.329200   10.000000    1.000000

# %%
data[['Age']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
type(data[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
print(data.loc[5, 'Age'])
print(type(data.loc[5, 'Age']))
# Out:
# nan
# <class 'numpy.float64'>

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch     Fare Cabin Embarked  Family  Alone Title
# 5       0      0   8.4583   NaN        Q       0      1    Mr
# 17      0      0  13.0000   NaN        S       0      1    Mr
# 19      0      0   7.2250   NaN        C       0      1   Mrs
# 26      0      0   7.2250   NaN        C       0      1    Mr
# 28      0      0   7.8792   NaN        Q       0      1  Miss

# %%
data['Age'].median()
# Out:
# np.float64(28.0)

# %%
data['Age_Median'] = data['Age'].fillna(data['Age'].median())

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch     Fare Cabin Embarked  Family  Alone Title  Age_Median
# 5       0      0   8.4583   NaN        Q       0      1    Mr        28.0
# 17      0      0  13.0000   NaN        S       0      1    Mr        28.0
# 19      0      0   7.2250   NaN        C       0      1   Mrs        28.0
# 26      0      0   7.2250   NaN        C       0      1    Mr        28.0
# 28      0      0   7.8792   NaN        Q       0      1  Miss        28.0

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked  Family  Alone Title  Age_Median  \
# 0      0   7.2500   NaN        S       1      0    Mr        22.0
# 1      0  71.2833   C85        C       1      0   Mrs        38.0
# 2      0   7.9250   NaN        S       0      1  Miss        26.0
# 3      0  53.1000  C123        S       1      0   Mrs        35.0
# 4      0   8.0500   NaN        S       0      1    Mr        35.0
#
#    Age_Median_Sex
# 0            22.0
# 1            38.0
# 2            26.0
# 3            35.0
# 4            35.0

# %%
data.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
data['Age_Median_Sex'] = data['Age'].fillna(data.groupby('Sex')['Age'].transform('median'))

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch     Fare Cabin Embarked  Family  Alone Title  Age_Median  \
# 5       0      0   8.4583   NaN        Q       0      1    Mr        28.0
# 17      0      0  13.0000   NaN        S       0      1    Mr        28.0
# 19      0      0   7.2250   NaN        C       0      1   Mrs        28.0
# 26      0      0   7.2250   NaN        C       0      1    Mr        28.0
# 28      0      0   7.8792   NaN        Q       0      1  Miss        28.0
#
#     Age_Median_Sex
# 5             29.0
# 17            29.0
# 19            27.0
# 26            29.0
# 28            27.0

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked  Family  Alone Title  Age_Median  \
# 0      0   7.2500   NaN        S       1      0    Mr        22.0
# 1      0  71.2833   C85        C       1      0   Mrs        38.0
# 2      0   7.9250   NaN        S       0      1  Miss        26.0
# 3      0  53.1000  C123        S       1      0   Mrs        35.0
# 4      0   8.0500   NaN        S       0      1    Mr        35.0
#
#    Age_Median_Sex
# 0            22.0
# 1            38.0
# 2            26.0
# 3            35.0
# 4            35.0

# %%
data.groupby('Sex')['Age'].transform('median').head()
# Out:
# 0    29.0
# 1    27.0
# 2    27.0
# 3    27.0
# 4    29.0
# Name: Age, dtype: float64

# %%
data["Age"].fillna(data.groupby('Sex')["Age"].transform('median')).head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    29.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %% [markdown]
# **Задание**
# Заполните осутствующие значения переменной возраст на основании титула.

# %%
data.groupby('Title')['Age'].median()
# Out:
# Title
# Master     3.5
# Misc      44.5
# Miss      21.0
# Mr        30.0
# Mrs       35.0
# Name: Age, dtype: float64

# %%
data['Age_Title_Median'] = data['Age'].fillna(data.groupby('Title')['Age'].transform('median'))

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch     Fare Cabin Embarked  Family  Alone Title  Age_Median  \
# 5       0      0   8.4583   NaN        Q       0      1    Mr        28.0
# 17      0      0  13.0000   NaN        S       0      1    Mr        28.0
# 19      0      0   7.2250   NaN        C       0      1   Mrs        28.0
# 26      0      0   7.2250   NaN        C       0      1    Mr        28.0
# 28      0      0   7.8792   NaN        Q       0      1  Miss        28.0
#
#     Age_Median_Sex Embarked_Mode  Age_Title_Median
# 5             29.0             Q              30.0
# 17            29.0             S              30.0
# 19            27.0             C              35.0
# 26            29.0             C              30.0
# 28            27.0             Q              21.0

# %%
data[data['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Fare Cabin Embarked  Family  Alone Title  \
# 61   female  38.0      0      0  80.0   B28      NaN       0      1  Miss
# 829  female  62.0      0      0  80.0   B28      NaN       0      1   Mrs
#
#      Age_Median  Age_Median_Sex
# 61         38.0            38.0
# 829        62.0            62.0

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
data['Embarked_Mode'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.loc[61]
# Out:
# PassengerId                        62
# Survived                            1
# Pclass                              1
# Name              Icard, Miss. Amelie
# Sex                            female
# Age                              38.0
# SibSp                               0
# Parch                               0
# Fare                             80.0
# Cabin                             B28
# Embarked                          NaN
# Family                              0
# Alone                               1
# Title                            Miss
# Age_Median                       38.0
# Age_Median_Sex                   38.0
# Embarked_Mode                       S
# Name: 61, dtype: object
